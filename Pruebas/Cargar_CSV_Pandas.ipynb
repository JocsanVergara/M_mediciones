# %%
# Importamos la librería de pandas
import pandas as pd
import matplotlib as plt

# %%
# Si nuestro archivo csv que estamos leyendo esta separado por comas
df = pd.read_csv("./Prueba.csv", encoding='latin-1')
# si estan separados por ";" usamos el argumento sep = ';' y si no tienen nombres los el argumento header = None , names =['nombre1','nombre2']
df.head()
# Out:
#                    Hora              Antena       iden.Tag  RSSI_1  \
# 0  2022/09/17/ 16:09:20  +UUDF:CCF957966B2C  :CCF957966B2C     -60
# 1  2022/09/17/ 16:09:20  +UUDF:CCF957966B2C  :CCF957966B2C     -60
# 2  2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -56
# 3  2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 4  2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -59
#
#    Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 0           -9            -12       0     37
# 1           -8             -6       0     37
# 2           -9            -12       0     38
# 3           -9            -12       0     37
# 4           -8             -6       0     37
#
#    Linea de visión libre(si=1, no=0)  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
#
# ...

# %%
# Seleccionar elementos por etiquetas
df.loc[1,'RSSI_1']
# Out:
# -60

# %%
# Seleccionar un elemento por número
df.iloc[1,3]
# Out:
# -60

# %%
# Seleccionar por columnas
df['RSSI_1']
# Out:
# 0     -60
# 1     -60
# 2     -56
# 3     -63
# 4     -59
#        ..
# 235   -57
# 236   -61
# 237   -61
# 238   -57
# 239   -57
# Name: RSSI_1, Length: 240, dtype: int64

# %%
# Seleccionar una fila
df.iloc[4]
# Out:
# Hora                                                 2022/09/17/ 16:09:21
# Antena                                                 +UUDF:CCF957966B2C
# iden.Tag                                                    :CCF957966B2C
# RSSI_1                                                                -59
# Ang.Azimuth                                                            -8
# Ang.Elevacion                                                          -6
# RSSI_2                                                                  0
# Canal                                                                  37
# Linea de visión libre(si=1, no=0)                                       1
# altura de la antena, respecto del nivel del suelo                     134
# Distancia entre antena con el tag en cm                                30
# Distancia entre el suelo con el tag en cm                             130
# Existe un error en la medición                                          0
# ...

# %%
# Seleccionar por condiciones booleana
df['RSSI_1']<-59
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 235    False
# 236     True
# 237     True
# 238    False
# 239    False
# Name: RSSI_1, Length: 240, dtype: bool

# %%
df[df['RSSI_1']<-59]
# Out:
#                      Hora              Antena       iden.Tag  RSSI_1  \
# 0    2022/09/17/ 16:09:20  +UUDF:CCF957966B2C  :CCF957966B2C     -60
# 1    2022/09/17/ 16:09:20  +UUDF:CCF957966B2C  :CCF957966B2C     -60
# 3    2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 5    2022/09/17/ 16:09:22  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 8    2022/09/17/ 16:09:23  +UUDF:CCF957966B2C  :CCF957966B2C     -60
# ..                    ...                 ...            ...     ...
# 228  2022/09/17/ 16:11:09  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 229  2022/09/17/ 16:11:10  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 233  2022/09/17/ 16:11:12  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 236  2022/09/17/ 16:11:13  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 237  2022/09/17/ 16:11:14  +UUDF:CCF957966B2C  :CCF957966B2C     -61
#
#      Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 0             -9            -12       0     37
# ...

# %% [markdown]
# Como ordenar columnas

# %%
# Ordenando de modo ascendente: de menor a mayor
df.sort_values('RSSI_1', ascending = True)
# Out:
#                      Hora              Antena       iden.Tag  RSSI_1  \
# 3    2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 5    2022/09/17/ 16:09:22  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 10   2022/09/17/ 16:09:24  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 170  2022/09/17/ 16:10:40  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 161  2022/09/17/ 16:10:36  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# ..                    ...                 ...            ...     ...
# 130  2022/09/17/ 16:10:20  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 135  2022/09/17/ 16:10:23  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 142  2022/09/17/ 16:10:26  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 123  2022/09/17/ 16:10:17  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 102  2022/09/17/ 16:10:06  +UUDF:CCF957966B2C  :CCF957966B2C     -54
#
#      Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 3             -9            -12       0     37
# ...

# %%
# Ordenar de forma descendente de mayor a menor
df.sort_values('RSSI_1', ascending = False)
# Out:
#                      Hora              Antena       iden.Tag  RSSI_1  \
# 102  2022/09/17/ 16:10:06  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 159  2022/09/17/ 16:10:35  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 142  2022/09/17/ 16:10:26  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 135  2022/09/17/ 16:10:23  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 130  2022/09/17/ 16:10:20  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# ..                    ...                 ...            ...     ...
# 66   2022/09/17/ 16:09:49  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 105  2022/09/17/ 16:10:08  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 10   2022/09/17/ 16:09:24  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 5    2022/09/17/ 16:09:22  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 3    2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -63
#
#      Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 102           -8            -17       0     38
# ...

# %%
# Ordenar por dos columnas
df.sort_values(['RSSI_1','Ang.Azimuth'], ascending = ['True','False'])
# Out:
#                      Hora              Antena       iden.Tag  RSSI_1  \
# 3    2022/09/17/ 16:09:21  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 5    2022/09/17/ 16:09:22  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 10   2022/09/17/ 16:09:24  +UUDF:CCF957966B2C  :CCF957966B2C     -63
# 47   2022/09/17/ 16:09:41  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# 48   2022/09/17/ 16:09:41  +UUDF:CCF957966B2C  :CCF957966B2C     -61
# ..                    ...                 ...            ...     ...
# 142  2022/09/17/ 16:10:26  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 159  2022/09/17/ 16:10:35  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 102  2022/09/17/ 16:10:06  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 123  2022/09/17/ 16:10:17  +UUDF:CCF957966B2C  :CCF957966B2C     -54
# 126  2022/09/17/ 16:10:18  +UUDF:CCF957966B2C  :CCF957966B2C     -54
#
#      Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 3             -9            -12       0     37
# ...

# %% [markdown]
# Si quieres crear listas a partir de datos y arreglos

# %%
# Tenemos una lista 
elemento1 = ['caracteristica 1',2,3]
elemento2 = ['caracteristica 1-2',2,3]
elemento3 = ['caracteristica 1-3',2,3]
lista = [elemento1,elemento2,elemento3]
#Creamos el dataframe a partir de la lista
pd.DataFrame(lista,
             columns = ['Columna1','columna2','columna3'])
# Out:
#              Columna1  columna2  columna3
# 0    caracteristica 1         2         3
# 1  caracteristica 1-2         2         3
# 2  caracteristica 1-3         2         3

# %%
#crear dataframe vacio
df_vacio = pd.DataFrame(columns = ['columna1','columna2','columna3'])
df_vacio
# Out:
# Empty DataFrame
# Columns: [columna1, columna2, columna3]
# Index: []

# %%
df_vacio = df_vacio.append({
    'columna1':'Dato1',
    'columna2':3,
    'columna3':1},ignore_index = True)
df_vacio
# Out:
#   columna1 columna2 columna3
# 0    Dato1        3        1

# %%
train = pd.read_csv('./../Base_datos/LOS_parcial/20220919_012311_134_70_130.csv', encoding='latin-1')
train.head()
# Out:
#                    Hora              Antena       iden.Tag  RSSI_1  \
# 0  2022/09/19/ 01:23:11  +UUDF:CCF957966B2C  :CCF957966B2C     -51
# 1  2022/09/19/ 01:23:12  +UUDF:CCF957966B2C  :CCF957966B2C     -50
# 2  2022/09/19/ 01:23:13  +UUDF:CCF957966B2C  :CCF957966B2C     -52
# 3  2022/09/19/ 01:23:13  +UUDF:CCF957966B2C  :CCF957966B2C     -52
# 4  2022/09/19/ 01:23:14  +UUDF:CCF957966B2C  :CCF957966B2C     -51
#
#    Ang.Azimuth  Ang.Elevacion  RSSI_2  Canal  \
# 0           -7             -3       0     38
# 1           -7             -3       0     39
# 2           -6             -3       0     37
# 3           -6             -3       0     38
# 4           -6             -3       0     39
#
#    Linea de visión libre(si=1, no=0)  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
#
# ...

# %% [markdown]
# 2. Exploración de datos

# %%
# que columnas tienen los datos?
train.columns
# Out:
# Index(['Hora', 'Antena', 'iden.Tag', 'RSSI_1', 'Ang.Azimuth', 'Ang.Elevacion',
#        'RSSI_2', 'Canal', 'Linea de visión libre(si=1, no=0)',
#        'altura de la antena, respecto del nivel del suelo',
#        'Distancia entre antena con el tag en cm',
#        'Distancia entre el suelo con el tag en cm',
#        'Existe un error en la medición'],
#       dtype='object')

# %%
# qué tamaño tienen los datos?
train.shape
# Out:
# (360, 13)

# %%
# existen datos nulos?
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 13 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Hora                                               360 non-null    object
#  1   Antena                                             360 non-null    object
#  2   iden.Tag                                           360 non-null    object
#  3   RSSI_1                                             360 non-null    int64
#  4   Ang.Azimuth                                        360 non-null    int64
#  5   Ang.Elevacion                                      360 non-null    int64
#  6   RSSI_2                                             360 non-null    int64
#  7   Canal                                              360 non-null    int64
#  8   Linea de visión libre(si=1, no=0)                  360 non-null    int64
# ...

# %%
# como se distribuyen las variables numéricas
train.describe()
# Out:
#            RSSI_1  Ang.Azimuth  Ang.Elevacion  RSSI_2       Canal  \
# count  360.000000   360.000000     360.000000   360.0  360.000000
# mean   -57.433333    -1.875000     -17.091667     0.0   37.986111
# std      8.328292     6.259783      19.659070     0.0    0.822610
# min    -73.000000    -7.000000     -47.000000     0.0   37.000000
# 25%    -61.250000    -7.000000     -44.000000     0.0   37.000000
# 50%    -53.000000    -6.000000      -3.000000     0.0   38.000000
# 75%    -51.000000     7.000000      -3.000000     0.0   39.000000
# max    -49.000000     8.000000      -2.000000     0.0   39.000000
#
#        Linea de visión libre(si=1, no=0)  \
# count                         360.000000
# mean                            0.666667
# std                             0.472061
# min                             0.000000
# 25%                             0.000000
# 50%                             1.000000
# 75%                             1.000000
# ...

# %%
# como se comportan las variables categoricas
#train.describe(include = ['0'])

# %% [markdown]
# 2.1 Estudio de algúnas variables

# %%
# Estudiaremos la relación entre las variaciones de la medicion con el indicador del error en la medicion
train.groupby(['Existe un error en la medición']).count()['Ang.Azimuth']
# Out:
# Existe un error en la medición
# 0    240
# 1    120
# Name: Ang.Azimuth, dtype: int64

# %%
train.groupby(['Ang.Azimuth','Existe un error en la medición']).count()['RSSI_1']
# Out:
# Ang.Azimuth  Existe un error en la medición
# -7           0                                 77
#              1                                 36
# -6           0                                 52
#              1                                 38
# -5           0                                 35
#  6           1                                 24
#  7           0                                 75
#              1                                 22
#  8           0                                  1
# Name: RSSI_1, dtype: int64

# %%
Asociando_errores.unstack(level = 0)
# Out:
# Ang.Azimuth                       -7    -6    -5     6     7    8
# Existe un error en la medición
# 0                               77.0  52.0  35.0   NaN  75.0  1.0
# 1                               36.0  38.0   NaN  24.0  22.0  NaN

# %%
import matplotlib.pyplot as plt

# %%
Asociando_errores = train.groupby(['Ang.Azimuth','Existe un error en la medición']).count()['RSSI_1']
print(Asociando_errores)
plt.plot(Asociando_errores.unstack(level = 0))
plt.show()
# Out:
# Ang.Azimuth  Existe un error en la medición
# -7           0                                 77
#              1                                 36
# -6           0                                 52
#              1                                 38
# -5           0                                 35
#  6           1                                 24
#  7           0                                 75
#              1                                 22
#  8           0                                  1
# Name: RSSI_1, dtype: int64

# %%
(Asociando_errores.unstack(level = 0).plot.bar())
plt.show()

# %% [markdown]
# Procesamiento de los datos

# %%
train[['RSSI_1','Ang.Azimuth', 'Ang.Elevacion','altura de la antena, respecto del nivel del suelo',
       'Distancia entre antena con el tag en cm',
       'Distancia entre el suelo con el tag en cm',
       'Existe un error en la medición']].head()
# Out:
#    RSSI_1  Ang.Azimuth  Ang.Elevacion  \
# 0     -51           -7             -3
# 1     -50           -7             -3
# 2     -52           -6             -3
# 3     -52           -6             -3
# 4     -51           -6             -3
#
#    altura de la antena, respecto del nivel del suelo  \
# 0                                                134
# 1                                                134
# 2                                                134
# 3                                                134
# 4                                                134
#
#    Distancia entre antena con el tag en cm  \
# 0                                       70
# 1                                       70
# 2                                       70
# 3                                       70
# 4                                       70
#
#    Distancia entre el suelo con el tag en cm  Existe un error en la medición
# ...

# %%
train[['RSSI_1','Ang.Azimuth', 'Ang.Elevacion','altura de la antena, respecto del nivel del suelo',
       'Distancia entre antena con el tag en cm',
       'Distancia entre el suelo con el tag en cm',
       'Existe un error en la medición']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 7 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   RSSI_1                                             360 non-null    int64
#  1   Ang.Azimuth                                        360 non-null    int64
#  2   Ang.Elevacion                                      360 non-null    int64
#  3   altura de la antena, respecto del nivel del suelo  360 non-null    int64
#  4   Distancia entre antena con el tag en cm            360 non-null    int64
#  5   Distancia entre el suelo con el tag en cm          360 non-null    int64
#  6   Existe un error en la medición                     360 non-null    int64
# dtypes: int64(7)
# memory usage: 19.8 KB
